# %%
import pandas as pd
import seaborn as sn

# %%
df = pd.read_csv('./IAKR7EFL_1.csv')

# %%
df
# Out:
#        Type of place of residence  Source of drinking water  \
# 0                               2                        14
# 1                               2                        12
# 2                               2                        12
# 3                               2                        12
# 4                               2                        12
# ...                           ...                       ...
# 31266                           2                        21
# 31267                           2                        21
# 31268                           2                        14
# 31269                           2                        14
# 31270                           2                        21
#
#        Number of household members  \
# 0                                6
# 1                                6
# 2                                3
# 3                                5
# 4                                4
# ...

# %%
df.columns
# Out:
# Index(['Type of place of residence', 'Source of drinking water',
#        'Number of household members',
#        'Number of children 5 and under in household', 'Sex of household head',
#        'Toilet facilities shared with other households',
#        'Wealth index combined', 'Wealth index factor score combined',
#        'Wealth index for urban/rural',
#        'Wealth index factor score for urban/rural',
#        'Number of living children', 'Marriage to first birth interval',
#        'Currently breastfeeding', 'Gave child plain water', 'Gave child juice',
#        'Gave child tinned, powdered or fresh milk ', 'Gave child baby formula',
#        'Gave child fortified baby food (cerelac, etc)',
#        'Gave child soup/clear broth', 'Gave child other liquid',
#        'Gave child CS foods',
#        'Gave child bread, noodles, other made from grain',
#        'Gave child potatoes, cassava, or other tubers', 'Gave child eggs',
#        'ave child pumpkin, carrots, squash',
# ...

# %%
df2 = df[["Mother's weight in kilograms", "Mother's height in centimeters", "Childs's weight in kilograms", 
         "Childs's height in centimeters", "Child's Height/Age standard deviation",
          "Childs's Weight/Age standard deviation","Childs's Weight/Height standard deviation"]]

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                             438.0                          1406.0
# 2                             753.0                          1573.0
# 5                             801.0                          1617.0
# 7                             600.0                          1394.0
# 9                             420.0                          1461.0
# ...                             ...                             ...
# 31266                         370.0                          1491.0
# 31267                         370.0                          1491.0
# 31268                         398.0                          1350.0
# 31269                         398.0                          1350.0
# 31270                         543.0                          1591.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2.isna().sum()
# Out:
# Mother's weight in kilograms                 0
# Mother's height in centimeters               0
# Childs's weight in kilograms                 0
# Childs's height in centimeters               0
# Child's Height/Age standard deviation        0
# Childs's Weight/Age standard deviation       0
# Childs's Weight/Height standard deviation    0
# dtype: int64

# %%
df2["Child\'s Height/Age standard deviation"]=df2["Child\'s Height/Age standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
indexNames = df2[df2['Child\'s Height/Age standard deviation'] == 9999.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1542101557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Child\'s Height/Age standard deviation"]=df2["Child\'s Height/Age standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1542101557.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
print(df2.shape)
print(df2['Child\'s Height/Age standard deviation'].max())
print(df2['Child\'s Height/Age standard deviation'].min())
# Out:
# (29560, 7)
# 600.0
# -599.0

# %%
print(df2['Child\'s Height/Age standard deviation'].unique())
df2['Child\'s Height/Age standard deviation'] = df2['Child\'s Height/Age standard deviation']/100
# Out:
# [ 509.  497.   14. ... -497.  397.  535.]
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1359096643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Child\'s Height/Age standard deviation'] = df2['Child\'s Height/Age standard deviation']/100

# %%
print(df2['Child\'s Height/Age standard deviation'].unique())
# Out:
# [ 5.09  4.97  0.14 ... -4.97  3.97  5.35]

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                             438.0                          1406.0
# 2                             753.0                          1573.0
# 5                             801.0                          1617.0
# 7                             600.0                          1394.0
# 9                             420.0                          1461.0
# ...                             ...                             ...
# 31266                         370.0                          1491.0
# 31267                         370.0                          1491.0
# 31268                         398.0                          1350.0
# 31269                         398.0                          1350.0
# 31270                         543.0                          1591.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2["Childs\'s Weight/Age standard deviation"]=df2["Childs\'s Weight/Age standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
indexNames = df2[df2['Childs\'s Weight/Age standard deviation'] == 9999.0].index
df2.drop(indexNames , inplace=True)
print(df2.shape)
print(df2['Childs\'s Weight/Age standard deviation'].max())
print(df2['Childs\'s Weight/Age standard deviation'].min())
# Out:
# (29560, 7)
# 577.0
# -576.0
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/2026398106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Childs\'s Weight/Age standard deviation"]=df2["Childs\'s Weight/Age standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/2026398106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2['Childs\'s Weight/Age standard deviation'] = df2['Childs\'s Weight/Age standard deviation']/100
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1093142076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Childs\'s Weight/Age standard deviation'] = df2['Childs\'s Weight/Age standard deviation']/100

# %%
print(df2['Childs\'s Weight/Age standard deviation'].unique())
# Out:
# [ 1.22        1.49        3.35        2.94        5.06386422 -2.18
#  -1.92       -2.01       -2.57       -1.95       -2.47       -2.46
#  -2.41       -1.23       -0.59       -1.88       -0.37       -0.98
#  -0.26       -2.64       -1.39       -0.24       -1.94       -2.5
#  -2.63       -0.89       -2.45       -0.23       -1.09       -1.12
#  -1.91        0.16       -1.15        0.45       -0.63       -0.3
#   0.83        0.36        0.98       -1.82       -1.66       -1.05
#  -4.13       -2.66       -2.35       -1.89       -0.11       -1.6
#  -2.4         2.79        3.23       -0.84        0.82       -3.11
#  -2.87       -2.         -0.41       -0.74       -1.68       -0.66
#  -4.47       -2.23       -1.55       -2.27       -3.12        2.62
#   1.52        1.85        1.68        1.33       -2.54        3.13
#   0.97       -0.93       -1.47       -3.05       -0.77       -3.08
#  -2.32        0.64       -1.48       -2.2        -1.64       -2.09
# ...

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                             438.0                          1406.0
# 2                             753.0                          1573.0
# 5                             801.0                          1617.0
# 7                             600.0                          1394.0
# 9                             420.0                          1461.0
# ...                             ...                             ...
# 31266                         370.0                          1491.0
# 31267                         370.0                          1491.0
# 31268                         398.0                          1350.0
# 31269                         398.0                          1350.0
# 31270                         543.0                          1591.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2["Childs\'s Weight/Height standard deviation"]=df2["Childs\'s Weight/Height standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
indexNames = df2[df2['Childs\'s Weight/Height standard deviation'] == 9999.0].index
df2.drop(indexNames , inplace=True)
print(df2.shape)
print(df2['Childs\'s Weight/Height standard deviation'].max())
print(df2['Childs\'s Weight/Height standard deviation'].min())
# Out:
# (29559, 7)
# 599.0
# -400.0
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/3534248756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Childs\'s Weight/Height standard deviation"]=df2["Childs\'s Weight/Height standard deviation"].replace({9998.0:9999.0, 9996.0:9999.0, 9997.0:9999.0})
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/3534248756.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2['Childs\'s Weight/Height standard deviation'].unique()
# Out:
# array([-161.        , -116.        ,  437.        ,  336.        ,
#         549.34823896, -150.        , -184.        , -115.        ,
#        -183.        ,  -81.        , -159.        , -177.        ,
#        -175.        ,  -19.        , -210.        ,   20.        ,
#        -263.        ,  -73.        ,  116.        ,   57.        ,
#        -325.        , -206.        ,  -69.        , -271.        ,
#        -153.        , -192.        ,  -32.        , -205.        ,
#        -101.        , -254.        , -155.        , -179.        ,
#          97.        ,  174.        ,  298.        , -251.        ,
#        -110.        ,  126.        ,  166.        ,  -39.        ,
#          -4.        , -102.        ,    9.        , -106.        ,
#        -190.        ,  -36.        ,    1.        ,   91.        ,
#        -185.        , -274.        ,  323.        ,  167.        ,
#         -86.        ,   83.        , -245.        , -257.        ,
# ...

# %%
df2['Childs\'s Weight/Height standard deviation'] = df2['Childs\'s Weight/Height standard deviation']/100
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/27526231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Childs\'s Weight/Height standard deviation'] = df2['Childs\'s Weight/Height standard deviation']/100

# %%
df2['Childs\'s Weight/Height standard deviation'].unique()
# Out:
# array([-1.61      , -1.16      ,  4.37      ,  3.36      ,  5.49348239,
#        -1.5       , -1.84      , -1.15      , -1.83      , -0.81      ,
#        -1.59      , -1.77      , -1.75      , -0.19      , -2.1       ,
#         0.2       , -2.63      , -0.73      ,  1.16      ,  0.57      ,
#        -3.25      , -2.06      , -0.69      , -2.71      , -1.53      ,
#        -1.92      , -0.32      , -2.05      , -1.01      , -2.54      ,
#        -1.55      , -1.79      ,  0.97      ,  1.74      ,  2.98      ,
#        -2.51      , -1.1       ,  1.26      ,  1.66      , -0.39      ,
#        -0.04      , -1.02      ,  0.09      , -1.06      , -1.9       ,
#        -0.36      ,  0.01      ,  0.91      , -1.85      , -2.74      ,
#         3.23      ,  1.67      , -0.86      ,  0.83      , -2.45      ,
#        -2.57      , -2.86      ,  0.15      , -0.58      ,  0.31      ,
#        -1.56      , -0.89      , -2.76      , -1.48      , -1.26      ,
# ...

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                             438.0                          1406.0
# 2                             753.0                          1573.0
# 5                             801.0                          1617.0
# 7                             600.0                          1394.0
# 9                             420.0                          1461.0
# ...                             ...                             ...
# 31266                         370.0                          1491.0
# 31267                         370.0                          1491.0
# 31268                         398.0                          1350.0
# 31269                         398.0                          1350.0
# 31270                         543.0                          1591.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2["Mother's weight in kilograms"].unique()
# Out:
# array([ 438.        ,  753.        ,  801.        ,  600.        ,
#         420.        ,  745.        ,  602.        ,  577.        ,
#         578.        ,  557.        ,  584.        ,  604.        ,
#         624.        ,  496.        ,  811.        ,  633.        ,
#         631.        ,  721.        ,  613.        ,  644.        ,
#         614.        ,  565.        ,  598.        ,  524.        ,
#         610.        ,  728.        ,  513.        ,  627.        ,
#         514.        ,  595.        ,  652.        ,  555.        ,
#         502.        ,  494.        ,  506.        ,  813.        ,
#         589.        ,  691.        ,  603.        ,  771.        ,
#         804.        ,  535.        ,  544.        ,  572.        ,
#         815.        ,  560.        ,  723.        ,  505.        ,
#         701.        ,  568.        ,  637.        ,  520.        ,
#         533.        ,  601.        ,  583.        ,  623.        ,
# ...

# %%
df2["Mother's weight in kilograms"] = df2["Mother's weight in kilograms"].apply(lambda x: x / 10)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/3649002375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Mother's weight in kilograms"] = df2["Mother's weight in kilograms"].apply(lambda x: x / 10)

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                          1406.0
# 2                              75.3                          1573.0
# 5                              80.1                          1617.0
# 7                              60.0                          1394.0
# 9                              42.0                          1461.0
# ...                             ...                             ...
# 31266                          37.0                          1491.0
# 31267                          37.0                          1491.0
# 31268                          39.8                          1350.0
# 31269                          39.8                          1350.0
# 31270                          54.3                          1591.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2[df2["Mother's weight in kilograms"] > 110]
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 128                           999.4                          9994.0
# 221                           999.5                          9995.0
# 270                           149.7                          1507.0
# 284                           999.4                          9994.0
# 285                           999.4                          9994.0
# ...                             ...                             ...
# 31085                         999.5                          9995.0
# 31086                         999.5                          9995.0
# 31107                         999.4                          9994.0
# 31108                         999.4                          9994.0
# 31109                         999.4                          9994.0
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 128                       42.000000                      601.000000
# ...

# %%
indexNames = df2[df2["Mother's weight in kilograms"] > 120.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/910554775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2["Mother's weight in kilograms"].unique()
# Out:
# array([ 43.8       ,  75.3       ,  80.1       ,  60.        ,
#         42.        ,  74.5       ,  60.2       ,  57.7       ,
#         57.8       ,  55.7       ,  58.4       ,  60.4       ,
#         62.4       ,  49.6       ,  81.1       ,  63.3       ,
#         63.1       ,  72.1       ,  61.3       ,  64.4       ,
#         61.4       ,  56.5       ,  59.8       ,  52.4       ,
#         61.        ,  72.8       ,  51.3       ,  62.7       ,
#         51.4       ,  59.5       ,  65.2       ,  55.5       ,
#         50.2       ,  49.4       ,  50.6       ,  81.3       ,
#         58.9       ,  69.1       ,  60.3       ,  77.1       ,
#         80.4       ,  53.5       ,  54.4       ,  57.2       ,
#         81.5       ,  56.        ,  72.3       ,  50.5       ,
#         70.1       ,  56.8       ,  63.7       ,  52.        ,
#         53.3       ,  60.1       ,  58.3       ,  62.3       ,
#         63.4       ,  55.1       ,  53.1       ,  59.9       ,
# ...

# %%
df["Mother's height in centimeters"].unique()
# Out:
# array([1406.        , 1573.        , 1617.        , 1394.        ,
#        1461.        , 1582.        , 1604.        , 1584.        ,
#        1564.        , 1547.        , 1567.        , 1578.        ,
#        1474.        , 1561.        , 1671.        , 1581.        ,
#        1491.        , 1593.        , 1574.        , 1548.        ,
#        1554.        , 1588.        , 1528.        , 1585.        ,
#        1523.        , 1536.        , 1587.        , 1565.        ,
#        1509.        , 1594.        , 1556.        , 1583.        ,
#        1531.        , 1615.        , 1614.        , 1543.        ,
#        1666.        , 1611.        , 1498.        , 1605.        ,
#        1493.        , 1632.        , 1535.        , 1495.        ,
#        1577.        , 1596.        , 1590.        , 1592.        ,
#        1503.        , 1613.        , 1568.        , 1624.        ,
#        1612.        , 1514.        , 1499.        , 1488.        ,
# ...

# %%
df2["Mother's height in centimeters"] = df2["Mother's height in centimeters"].apply(lambda x: x / 10)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/3614393278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Mother's height in centimeters"] = df2["Mother's height in centimeters"].apply(lambda x: x / 10)

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                           140.6
# 2                              75.3                           157.3
# 5                              80.1                           161.7
# 7                              60.0                           139.4
# 9                              42.0                           146.1
# ...                             ...                             ...
# 31266                          37.0                           149.1
# 31267                          37.0                           149.1
# 31268                          39.8                           135.0
# 31269                          39.8                           135.0
# 31270                          54.3                           159.1
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
indexNames = df2[df2["Mother's height in centimeters"] < 125.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1246585681.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
indexNames = df2[df2["Mother's height in centimeters"] > 185.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/3928539356.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                           140.6
# 2                              75.3                           157.3
# 5                              80.1                           161.7
# 7                              60.0                           139.4
# 9                              42.0                           146.1
# ...                             ...                             ...
# 31266                          37.0                           149.1
# 31267                          37.0                           149.1
# 31268                          39.8                           135.0
# 31269                          39.8                           135.0
# 31270                          54.3                           159.1
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                        111.000000                      900.000000
# ...

# %%
df2["Childs's weight in kilograms"] = df2["Childs's weight in kilograms"].apply(lambda x: x/ 10)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/433552965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Childs's weight in kilograms"] = df2["Childs's weight in kilograms"].apply(lambda x: x/ 10)

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                           140.6
# 2                              75.3                           157.3
# 5                              80.1                           161.7
# 7                              60.0                           139.4
# 9                              42.0                           146.1
# ...                             ...                             ...
# 31266                          37.0                           149.1
# 31267                          37.0                           149.1
# 31268                          39.8                           135.0
# 31269                          39.8                           135.0
# 31270                          54.3                           159.1
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                         11.100000                      900.000000
# ...

# %%
df2[df2["Childs's weight in kilograms"] > 60]
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 288                            66.3                           162.3
# 576                            62.4                           163.5
# 606                            55.7                           155.9
# 1123                           54.8                           159.3
# 1332                           55.2                           151.3
# ...                             ...                             ...
# 31082                          47.4                           149.4
# 31097                          51.5                           157.1
# 31147                          40.4                           149.2
# 31227                          43.1                           152.2
# 31235                          33.1                           144.9
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 288                           999.5                          9995.0
# ...

# %%
indexNames = df2[df2["Childs's weight in kilograms"] > 80.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1696213768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2["Childs's weight in kilograms"].max()
# Out:
# 48.58887945093775

# %%
df2["Childs's weight in kilograms"].min()
# Out:
# 0.5

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                           140.6
# 2                              75.3                           157.3
# 5                              80.1                           161.7
# 7                              60.0                           139.4
# 9                              42.0                           146.1
# ...                             ...                             ...
# 31266                          37.0                           149.1
# 31267                          37.0                           149.1
# 31268                          39.8                           135.0
# 31269                          39.8                           135.0
# 31270                          54.3                           159.1
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                         11.100000                      900.000000
# ...

# %%
df2["Childs's height in centimeters"] = df2["Childs's height in centimeters"].apply(lambda x: x / 10)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1846457762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Childs's height in centimeters"] = df2["Childs's height in centimeters"].apply(lambda x: x / 10)

# %%
indexNames = df2[df2["Childs's height in centimeters"] > 140.0].index
df2.drop(indexNames , inplace=True)
# Out:
# C:\Users\bunty\AppData\Local\Temp/ipykernel_11236/1590927375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(indexNames , inplace=True)

# %%
df2["Childs's height in centimeters"].max()
# Out:
# 132.5

# %%
df2
# Out:
#        Mother's weight in kilograms  Mother's height in centimeters  \
# 1                              43.8                           140.6
# 2                              75.3                           157.3
# 5                              80.1                           161.7
# 7                              60.0                           139.4
# 9                              42.0                           146.1
# ...                             ...                             ...
# 31266                          37.0                           149.1
# 31267                          37.0                           149.1
# 31268                          39.8                           135.0
# 31269                          39.8                           135.0
# 31270                          54.3                           159.1
#
#        Childs's weight in kilograms  Childs's height in centimeters  \
# 1                         11.100000                       90.000000
# ...

# %%
df2.to_csv('malnutrition.csv',index=False)

# %%
sn.heatmap(data = df2)
# Out:
# <AxesSubplot:>

# %%
sn.swarmplot(x="Mother's weight in kilograms",y="Childs's Weight/Height standard deviation",data=df2,palette='Set2')
# Out:
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
